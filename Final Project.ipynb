# %%
import random

def usermove():
    user_choice = input("Choose: Rock, Paper, or Scissors") #lets user choose what move to play
    if user_choice == "Rock":
        user_move = "Rock" #checks if the user chose rock, and assigns it
        print("You chose",user_move)
        return user_move
    elif user_choice == "Paper":
        user_move = "Paper"
        print("You chose",user_move)
        return user_move
    elif user_choice == "Scissors":
        user_move = "Scissors"
        print("You chose",user_move)
        return user_move
    else:
        user_move = "Error" #lets user know they did the input wrong
        print("Not a valid option. Did you remember to capitalize?")
        return user_move

def randomcomp():
    moves = ["Rock", "Paper", "Scissors"]
    comp_move = random.choice(moves) #randomly chooses one of the 3 moves
    return comp_move

def results(user, computer):
    print("Rock")
    print("Paper")
    print("Scissors")
    print("Computer chose", computer)
    if user == "Rock": #Outputs the result if user chose rock
        if computer == "Rock":
            print("It's a tie!")
        elif computer == "Paper":
            print("You lose!")
        elif computer == "Scissors":
            print("You win!")
        else:
            print("There was an error, and the game could not be played.")
    elif user == "Paper":
        if computer == "Rock":
            print("You win!")
        elif computer == "Paper":
            print("It's a tie!")
        elif computer == "Scissors":
            print("You lose!")
        else:
            print("There was an error, and the game could not be played.")
    elif user == "Scissors":
        if computer == "Rock":
            print("You lose!")
        elif computer == "Paper":
            print("You win!")
        elif computer == "Scissors":
            print("It's a tie!")
        else:
            print("There was an error, and the game could not be played.")
    else: 
        print ("There was an error, and the game could not be played.") #outputs if there was something wrong with user's input
            
def main():
    user = usermove()
    computer = randomcomp()
    results(user, computer)

if __name__ == "__main__":
    main()
# Out:
# Choose: Rock, Paper, or Scissorsrip
# Not a valid option. Did you remember to capitalize?
# Rock
# Paper
# Scissors
# Computer chose Paper
# There was an error, and the game could not be played.
